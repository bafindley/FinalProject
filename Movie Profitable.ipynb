# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file2 = 'csv/movie_profitable_cleaned.csv'
df = pd.read_csv(file2)
list(df.columns.values)
df
# Out:
#       Unnamed: 0                                   Movie Title  \
# 0              0                                       Avatar
# 1              1     Pirates of the Caribbean: At World's End
# 2              2                                      Spectre
# 3              3                        The Dark Knight Rises
# 4              4                                  John Carter
# 5              5                                 Spider-Man 3
# 6              6                                      Tangled
# 7              7                      Avengers: Age of Ultron
# 8              8       Harry Potter and the Half-Blood Prince
# 9              9           Batman v Superman: Dawn of Justice
# 10            10                             Superman Returns
# 11            11                            Quantum of Solace
# 12            12   Pirates of the Caribbean: Dead Man's Chest
# 13            13                              The Lone Ranger
# ...

# %%
dir = df.groupby('Director')['Profit / Loss'].nunique()
dir
# Out:
# Director
# Aaron Schneider                1
# Aaron Seltzer                  1
# Abel Ferrara                   1
# Adam Goldberg                  1
# Adam Marcus                    1
# Adam McKay                     6
# Adam Rapp                      1
# Adam Rifkin                    1
# Adam Shankman                  8
# Adrian Lyne                    4
# Adrienne Shelly                1
# Agnieszka Holland              1
# Agnieszka Wojtowicz-Vosloo     1
# Aki Kaurismäki                 1
# Akira Kurosawa                 1
# Akiva Goldsman                 1
# Akiva Schaffer                 1
# Alan Cohn                      1
# Alan J. Pakula                 2
# Alan Metter                    1
# Alan Parker                    3
# Alan Poul                      1
# Alan Rudolph                   1
# Alan Shapiro                   1
# Alan Taylor                    2
# Albert Brooks                  1
# Albert Hughes                  3
# Alejandro Agresti              1
# ...
