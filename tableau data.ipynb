# %%
import pandas as pd
from nltk import word_tokenize
import os 
import glob
import matplotlib.pyplot as plt

csv = 'csv/responses_easter.csv'
df = pd.read_csv(csv)
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (8,6)
plt.rcParams['font.size'] = 12

# %%
df
# Out:
#                                              Unnamed: 0  Unnamed: 1  \
# 0     Lillian Gish, Mae Marsh, Henry B. Walthall, Mi...         NaN
# 1     Dan Hanlon, Edna Pendleton, Curtis Benton, All...         NaN
# 2     Lillian Gish, Mae Marsh, Robert Harron, F.A. T...         NaN
# 3     Mary Carr, James Sheridan, Noel Tearle, Willia...         NaN
# 4     Carl Miller, Edna Purviance, Jackie Coogan, Ch...         NaN
# 5     Douglas Fairbanks, Snitz Edwards, Charles Belc...         NaN
# 6     John Gilbert, Renée Adorée, Hobart Bosworth, C...         NaN
# 7     Aleksandr Antonov, Vladimir Barskiy, Grigoriy ...         NaN
# 8     Mae Murray, John Gilbert, Roy D'Arcy, Josephin...         NaN
# 9     Alfred Abel, Gustav Fröhlich, Rudolf Klein-Rog...         NaN
# 10    Mary Pickford, Roy Stewart, Mary Louise Miller...         NaN
# 11    Mary Pickford, Charles 'Buddy' Rogers, Sunshin...         NaN
# 12    George O'Brien, Janet Gaynor, Margaret Livings...         NaN
# ...
